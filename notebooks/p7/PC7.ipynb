# %% [markdown]
# # Welcome to the <span style="color:blue">Statistical Methods of Language Technologyb SoSe21</span> course
# ###  Dr. Seid Muhie Yimam
#    * Email: yimam@informatik.uni-hamburg.de
#    * Office: Informatikum, F-415
#
# ###  Dr. Özge Alaçam
#    * Email: alacam@informatik.uni-hamburg.de
#    * Office: Informatikum, F-435

# %% [markdown]
# ## Topic of this week;
# In this first practice class, we are going to focus on two main topics, which will be useful to complete the assignment;
# * CFGs and PCFG parsing
# * Parseval
#
#
# ## Deadline: 09/07 June
#
# ___

# %% [markdown]
# # <span style="color:red"> In class Exercises </span>

# %% [markdown]
# ## <span style="color:red"> Problem 7.1 CFGs and PCFG parsing </span>
#
# ###  <span style="color:red">a) Convert this CFG to CNF. Capital letters are non-terminals and lowercase letters are terminals, S is the start symbol. </span>
#
# \begin{align*}
# 	S~&\rightarrow~A~B~C~|~S~D~\\
# 	A~&\rightarrow~D~D~|~
# 	\epsilon~\\
# 	B~&\rightarrow~F~|~C~C~C~\\
# 	C~&\rightarrow~a~c~|~a~d~|~a~e~|~\epsilon~\\
# 	D~&\rightarrow~C~d~d~|~d~e~\\
# 	F~&\rightarrow~\epsilon~\\
# \end{align*}

# %% [markdown]
# # Context Free grammar to  Chomsky normal form (CNF) conversion
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  ###  <span style="color:red"> b) Parse the sentence **“I see the man with the telescope** using the bottom up **CYK" algorithm (convert to CNF) </span>
#
#  Assume the following grammar:
# \begin{align*}%
# 	S~ &\rightarrow~NP~VP~~|~NP~\\
# 	VP~&\rightarrow~V~NP~|~V~NP~PP~\\
# 	NP~&\rightarrow~NP~PP~|~D~N~|~R~\\
# 	PP~&\rightarrow~P~NP~\\
# 	P~&\rightarrow~with~|~in~|~of~\\
# 	V~&\rightarrow~see~|~take~|~make~\\
# 	N~&\rightarrow~man~|~telescope~\\
# 	D~&\rightarrow~the~|~an~|~a~\\
# 	R~&\rightarrow~I~\\
# \end{align*}
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <span style="color:red">  c) Given the following grammar and lexicon rules, parse the sentence <it>``fruit flies like a banana''</it> with probabilistic CYK. </span>
#
#
#
# * Grammar
# \begin{align}
# S & \rightarrow & NP~~VP & ~~~1.0 \\
# NP & \rightarrow & D~~N & ~~~0.5 \\
# NP & \rightarrow & N~~N & ~~~0.3 \\
# NP & \rightarrow & NP~~PP & ~~~0.2 \\
# VP & \rightarrow  & V~~NP & ~~~0.6 \\
# VP & \rightarrow  & V~~PP & ~~~0.4 \\
# PP & \rightarrow  & P~~NP & ~~~1.0\\
# \end{align}
#
#
# * Lexicon
# \begin{align}
# N & \rightarrow  & fruit & ~~~0.2 \\
# V & \rightarrow & flies & ~~~0.1 \\
# N & \rightarrow & flies & ~~~0.1 \\
# V & \rightarrow & like & ~~~0.3 \\
# P & \rightarrow & like & ~~~0.2 \\
# D & \rightarrow & a & ~~~0.4 \\
# D & \rightarrow & the & ~~~0.5 \\
# N & \rightarrow & banana & ~~~0.1 \\
# N & \rightarrow & time & ~~~0.1 \\
# \end{align}

# %% [markdown]
# ### Hints from lecture Slides:
# <img src="SMoLT-06_StatParse_CNFConversion.png" width=60%>

# %% [markdown]
# ### Hints from lecture Slides:
#
# **First Steps**
# <img src="SMoLT-06_StatParse_CYK_parsing1.png" width=60%>

# %% [markdown]
# <embed src="tree1.pdf" type="application/pdf">

# %% [markdown]
# **Next Step**
# <img src="SMoLT-06_StatParse_CYK_parsing2.png" width=60%>

# %% [markdown]
# **Next Step**
# <img src="SMoLT-06_StatParse_CYK_parsing3.png" width=60%>

# %% [markdown]
# **Final Step**
# <img src="SMoLT-06_StatParse_PCFG.png" width=60%>
# <img src="SMoLT-06_StatParse_CYK_parsing_final.png" width=60%>

# %% [markdown]
# ## <span style="color:red"> Problem 7.2 Parse Evaluation </span>

# %% [markdown]
# ### <span style="color:red">  a) Compute Precision, Recall and F1 value for the following two parses, labeled and unlabeled. </span>

# %% [markdown]
# **System:**
# <img src="tree1.png" width=60%>

# %% [markdown]
# **Gold:**
# <img src="tree2x.png" width=60%>

# %% [markdown]
# ### <span style="color:red">  b) Convert the trees in a) into the Penn Treebank bracketed format. </span>
# **Hints from Lecture Slides:**
# <img src="SMoLT-06_StatParse_PT_format.png" width=60%>

# %% [markdown]
# ### <span style="color:red">  c) Familiarize with the Stanford CoreNLP Parser https://corenlp.run/ or http://nlp.stanford.edu:8080/parser/ . Parse a sentence and draw the tree (using constituency parse). Does your sentence make sense? </span>

# %%
(2 * (16/20)* (16/18) ) / ((16/20)+(16/18))
# Out:
# 0.8421052631578948

# %% [markdown]
# 7.2
# Compute Precision, Recall and F1 values for the following two parses
